# %%
import numpy as np

# %%
arr = np.array([[1,2,3] , [4,5,6] , [6,7,8] , [9,10,11]])

# %%
arr
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [ 6,  7,  8],
#        [ 9, 10, 11]])

# %%
flatt = arr.flatten()

# %%
flatt
# Out:
# array([ 1,  2,  3,  4,  5,  6,  6,  7,  8,  9, 10, 11])

# %%
arr[3:5]
# Out:
# array([[ 9, 10, 11]])

# %%
flatt[3:5]
# Out:
# array([4, 5])
